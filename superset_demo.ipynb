# %% [markdown]
# <img src="img/logo_negro.png" style="float: right; margin: 15px; ">
#
# <h1 style="margin: 15px; margin-left: 0px; ">Demostración de Apache SuperSet</h1>
# Marzo 1 de 2019 <br>
# Creado por: <a href="mailto:jorge.quintana@datalytics.com">Jorge Quintana</a>
#
# <br>
# <hr>
# <br>
# <img src="img/s.png" style="float: left; margin-right: 20px; height : 200px">
#
# <p style = "text-align: justify">
# Superset es una herramienta de visualización de datos desarrollado por AirBnB, pero donada a Apache Software Foundation y en estado de incubación bajo el patrocinio de Apache Incubator. Es definida como <b>"...a modern, enterprise-ready business intelligence web application..."</b>. Está desarrollada en Python, como Backend, y una mezcla de React.js, JavaScript y D3.js para el Frontend y utiliza el poder de los múltiples modulos con los que cuenta Python (SQLAlchemy, Pandas, Numpy, ...) para generar conexiones a diferentes fuentes de información -como lo son: Bases de Datos, Memorias Caches, DataLakes usando diferentes conectores- y procesansdo dichos datos por medio de una interfaz de SQL (SQLlab). Para más información véase <a href = "https://superset.incubator.apache.org">Apache Superset (Incubating)</a>
# </p>
# <br>
# <hr>

# %% [markdown]
# ### Caracterización de victimas del conflicto armado y beneficiarias de planes de ayuda económica.
#
# Importando un conjunto de datos de [Datos Abiertos](https://www.datos.gov.co/browse?q=Observatorio%20de%20paz&sortBy=relevance) sobre el registro y la caracterización de las victimas del conflicto armado y reportadas como beneficiarias de planes de ayuda. Datos reportados por el Ministerio de Interior.

# %%
import requests
import pandas as pd

def get_data(dataset: str, pags: int, limit: int): 
    limit = 1000
    data = pd.DataFrame()
    
    if dataset == 'descripcion':
        for i in range(pags):
            offset = i * limit
            aux = requests.get('https://www.datos.gov.co/resource/9kvn-3qq8.json?$order=:id&$limit={}&$offset={}'.format(limit, offset))
            if aux.text != '[]\n':
                aux = pd.read_json(aux.text)
                
    else:
        data = requests.get('https://www.datos.gov.co/resource/g62i-exv7.json?$limit=1000')

# %%
data = pd.read_json(data.text)
data
# Out:
#     auxilio_econ_mico_mes  curso_de_vida edad grupo_etario hecho_victimizante  \
# 0              02 FEBRERO        Adultez   47      29 a 59     DESPLAZAMIENTO
# 1              02 FEBRERO        Jovenes   19      18 a 28     DESPLAZAMIENTO
# 2              02 FEBRERO        Jovenes   25      18 a 28     DESPLAZAMIENTO
# 3              02 FEBRERO        Adultez   38      29 a 59     DESPLAZAMIENTO
# 4              02 FEBRERO        Adultez   49      29 a 59     DESPLAZAMIENTO
# 5              02 FEBRERO        Jovenes   21      18 a 28     DESPLAZAMIENTO
# 6              02 FEBRERO        Jovenes   28      18 a 28     DESPLAZAMIENTO
# 7              02 FEBRERO        Adultez   33      29 a 59     DESPLAZAMIENTO
# 8              02 FEBRERO        Adultez   48      29 a 59     DESPLAZAMIENTO
# 9              02 FEBRERO  Persona Mayor   74     60 y mas     DESPLAZAMIENTO
# 10             02 FEBRERO        Adultez   30      29 a 59     DESPLAZAMIENTO
# ...

# %%
data.groupby('vigencia').count().sexo
# Out:
# vigencia
# 2017    364
# 2018    390
# 2019     28
# Name: sexo, dtype: int64

# %%
# Out:
#     actoterrorista adultomayor afrodescendiente amenaza apoyo  \
# 0               NO          NO               NO      NO    NO
# 1               NO          NO               NO      NO    NO
# 2               NO          NO               NO      NO    NO
# 3               NO          NO               NO      NO    NO
# 4               NO          NO               NO      NO    NO
# 5               NO          NO               NO      NO    NO
# 6               NO          NO               NO      NO    NO
# 7               NO          NO               NO      NO    NO
# 8               NO          NO               NO      NO    NO
# 9               NO          NO               NO      NO    NO
# 10              NO          NO               NO      NO    NO
# 11              NO          NO               NO      NO    NO
# 12              NO          NO               NO      SI    NO
# 13              NO          NO               NO      NO    NO
# ...

# %%
range(10)
# Out:
# range(0, 10)
